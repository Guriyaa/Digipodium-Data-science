# %%
import pandas as pd
import  numpy as np
import plotly.express as px

# %%
df = pd.read_json('flipkart_fashion_products_dataset.json')
df.head()
# Out:
#                                     _id actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# 2  Yorker trackpants made from 100% rich combed c...  68% off
# 3  Yorker trackpants made from 100% rich combed c...  69% off
# 4  Yorker trackpants made from 100% rich combed c...  68% off
#
#                                               images  out_of_stock  \
# 0  [https://rukminim1.flixcart.com/image/128/128/...         False
# 1  [https://rukminim1.flixcart.com/image/128/128/...         False
# 2  [https://rukminim1.flixcart.com/image/128/128/...         False
# 3  [https://rukminim1.flixcart.com/image/128/128/...         False
# 4  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                 pid                                    product_details  \
# 0  TKPFCZ9EA7H5FYZH  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1  TKPFCZ9EJZV2UVRZ  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2  TKPFCZ9EHFCY5Z4Y  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3  TKPFCZ9ESZZ7YWEF  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4  TKPFCZ9EVXKBSUD7  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller selling_price sub_category  \
# 0  Shyam Enterprises           921   Bottomwear
# 1  Shyam Enterprises           499   Bottomwear
# 2  Shyam Enterprises           931   Bottomwear
# 3  Shyam Enterprises           911   Bottomwear
# 4  Shyam Enterprises           943   Bottomwear
#
#                                title  \
# 0   Solid Men Multicolor Track Pants
# 1         Solid Men Blue Track Pants
# 2   Solid Men Multicolor Track Pants
# 3   Solid Men Multicolor Track Pants
# 4  Solid Men Brown, Grey Track Pants
#
#                                                  url
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...

# %%
df['actual_price'].str.replace(',','')
# Out:
# 0        2999
# 1        1499
# 2        2999
# 3        2999
# 4        2999
#          ...
# 29995    2299
# 29996     799
# 29997    4999
# 29998    3125
# 29999    3125
# Name: actual_price, Length: 30000, dtype: object

# %%
def clean_price(value):
    if not value:
        return np.nan
    elif isinstance(value, str):
        value = value.replace(',','')
        if value.isnumeric():    
            return float(value)
    else:   
      return value

df['actual_price'].apply(clean_price)
# Out:
# 0        2999.0
# 1        1499.0
# 2        2999.0
# 3        2999.0
# 4        2999.0
#           ...
# 29995    2299.0
# 29996     799.0
# 29997    4999.0
# 29998    3125.0
# 29999    3125.0
# Name: actual_price, Length: 30000, dtype: float64

# %%
df['actual_price'] = df['actual_price'].apply(clean_price)# actual implementation
df['selling_price'] = df['actual_price'].apply(clean_price)# actual implementation

# %%
df.head()
# Out:
#                                     _id  actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2999.0            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1499.0            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2999.0            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2999.0            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2999.0            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# 2  Yorker trackpants made from 100% rich combed c...  68% off
# 3  Yorker trackpants made from 100% rich combed c...  69% off
# 4  Yorker trackpants made from 100% rich combed c...  68% off
#
#                                               images  out_of_stock  \
# 0  [https://rukminim1.flixcart.com/image/128/128/...         False
# 1  [https://rukminim1.flixcart.com/image/128/128/...         False
# 2  [https://rukminim1.flixcart.com/image/128/128/...         False
# 3  [https://rukminim1.flixcart.com/image/128/128/...         False
# 4  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                 pid                                    product_details  \
# 0  TKPFCZ9EA7H5FYZH  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1  TKPFCZ9EJZV2UVRZ  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2  TKPFCZ9EHFCY5Z4Y  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3  TKPFCZ9ESZZ7YWEF  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4  TKPFCZ9EVXKBSUD7  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller  selling_price sub_category  \
# 0  Shyam Enterprises         2999.0   Bottomwear
# 1  Shyam Enterprises         1499.0   Bottomwear
# 2  Shyam Enterprises         2999.0   Bottomwear
# 3  Shyam Enterprises         2999.0   Bottomwear
# 4  Shyam Enterprises         2999.0   Bottomwear
#
#                                title  \
# 0   Solid Men Multicolor Track Pants
# 1         Solid Men Blue Track Pants
# 2   Solid Men Multicolor Track Pants
# 3   Solid Men Multicolor Track Pants
# 4  Solid Men Brown, Grey Track Pants
#
#                                                  url
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...

# %%
def clean_discount(value):
    if not value:
        return np.nan
    elif isinstance(value, str):
        value = value.replace('% off','')
        try:
            value = float(value)
            return value
        except:
            print(value)# get an idea of what value failed
            return np.nan
        else:
            return value
        
df['discount'].apply(clean_discount)
# Out:
# 0        69.0
# 1        66.0
# 2        68.0
# 3        69.0
# 4        68.0
#          ...
# 29995    40.0
# 29996    34.0
# 29997    40.0
# 29998    40.0
# 29999    40.0
# Name: discount, Length: 30000, dtype: float64

# %%
df['discount'] = df['discount'].apply(clean_discount)

# %%
def clean_rating(value):
    if value:
        return float(value)
    return np.nan

#test
df['average_rating'].apply(clean_rating)
# Out:
# 0        3.9
# 1        3.9
# 2        3.9
# 3        3.9
# 4        3.9
#         ...
# 29995    NaN
# 29996    3.8
# 29997    NaN
# 29998    3.8
# 29999    NaN
# Name: average_rating, Length: 30000, dtype: float64

# %%
df['average_rating'] = df['average_rating'].apply(clean_rating) #actual implementation

# %%
df.sort_values(by='selling_price', ascending = False)
# Out:
#                                         _id  actual_price  average_rating  \
# 10767  6de905cc-8da9-5ad9-9bec-4366f1a4b1a5       12999.0             2.8
# 10801  57ee7499-1446-59df-ab85-f941bd013bda       12999.0             2.3
# 27627  a0b220a6-da00-5e0a-a64e-ef78921d8e5d       12999.0             3.7
# 27809  0aaf9f32-c62e-5f86-bd88-f5dc5c846b68       12999.0             3.7
# 27971  47d09c94-3e3c-55b8-9611-906ce9bf7e3a       12999.0             4.5
# ...                                     ...           ...             ...
# 27949  1b7e9117-37c1-59c2-9152-19d4169879e5           NaN             3.6
# 27993  ef71773d-5a3c-5924-ae15-40e54a274d26           NaN             3.6
# 28100  efceb284-710b-5853-b707-4022ccdc2b44           NaN             5.0
# 28129  152cfd53-18e2-560a-a828-eeaf1688a20f           NaN             NaN
# 29488  d53cf2b5-44c6-5c30-a927-1a20ba80877c           NaN             NaN
#
#          brand                  category          crawled_at  \
# 10767  True Bl  Clothing and Accessories 2021-02-10 22:11:34
# 10801  True Bl  Clothing and Accessories 2021-02-10 22:12:01
# 27627       Pu  Clothing and Accessories 2021-02-11 01:09:12
# 27809       Pu  Clothing and Accessories 2021-02-11 01:10:48
# 27971       Pu  Clothing and Accessories 2021-02-11 01:12:12
# ...        ...                       ...                 ...
# 27949       Pu  Clothing and Accessories 2021-02-11 01:12:01
# 27993       Pu  Clothing and Accessories 2021-02-11 01:12:24
# 28100     GOT   Clothing and Accessories 2021-02-11 01:13:21
# 28129           Clothing and Accessories 2021-02-11 01:13:35
# 29488    Ravil  Clothing and Accessories 2021-02-11 01:27:34
#
#                                              description  discount  \
# 10767                                                         60.0
# 10801  A stellar option for smart events, True Blue's...      60.0
# 27627                  Stylish and trendy jacket for men      40.0
# 27809                  Stylish and trendy jacket for men      50.0
# 27971                                                         40.0
# ...                                                  ...       ...
# 27949  PRODUCT STORY Go beyond the expected in our Ev...       NaN
# 27993  PRODUCT STORY Go beyond the expected in our Ev...       NaN
# 28100                                                          NaN
# 28129                                                          NaN
# 29488                                                          NaN
#
#                                                   images  out_of_stock  \
# 10767  [https://rukminim1.flixcart.com/image/128/128/...          True
# 10801  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27627  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27809  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27971  [https://rukminim1.flixcart.com/image/128/128/...         False
# ...                                                  ...           ...
# 27949  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27993  [https://rukminim1.flixcart.com/image/128/128/...         False
# 28100  [https://rukminim1.flixcart.com/image/128/128/...         False
# 28129  [https://rukminim1.flixcart.com/image/128/128/...          True
# 29488  [https://rukminim1.flixcart.com/image/128/128/...          True
#
#                     pid                                    product_details  \
# 10767  SUIFPDS2DEZNSKTH  [{'Ideal For': 'Men'}, {'Occasion': 'Wedding'}...
# 10801  SUIFNMK2FQDWYTUZ  [{'Ideal For': 'Men'}, {'Occasion': 'Wedding'}...
# 27627  JCKFQF5KMJJ349H8  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27809  JCKFQF5K72AT2JDC  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27971  SWSFUMFGQFKVZGYH  [{'Color': 'Black'}, {'Fabric': 'Polyester'}, ...
# ...                 ...                                                ...
# 27949  TKPFVGH2AXMFVZF7  [{'Style Code': '58346901'}, {'Closure': 'Draw...
# 27993  TKPFVGH2AXMFVZF7  [{'Style Code': '58346901'}, {'Closure': 'Draw...
# 28100  TSHEHAENRET8HGAX  [{'Type': 'Polo Neck'}, {'Sleeve': 'Half Sleev...
# 28129  VESFZ5FW9KYBFJ9Z  [{'Pattern': 'Solid'}, {'Sleeve': 'Sleeveless'...
# 29488  TKPFZAGJYK9YGRAA  [{'Style Code': 'Broad-line'}, {'Closure': 'Dr...
#
#                     seller  selling_price                   sub_category  \
# 10767                             12999.0  Blazers, Waistcoats and Suits
# 10801  KAPSONSRETAILPVTLTD        12999.0  Blazers, Waistcoats and Suits
# 27627            RetailNet        12999.0                    Winter Wear
# 27809      PumaSportsIndia        12999.0                    Winter Wear
# 27971            RetailNet        12999.0                    Winter Wear
# ...                    ...            ...                            ...
# 27949      PumaSportsIndia            NaN                     Bottomwear
# 27993      PumaSportsIndia            NaN                     Bottomwear
# 28100                GOTIT            NaN                        Topwear
# 28129                                 NaN         Innerwear and Swimwear
# 29488                                 NaN                     Bottomwear
#
#                                        title  \
# 10767           2 Piece Self Design Men Suit
# 10801                 2 Piece Solid Men Suit
# 27627    Full Sleeve Solid Men Casual Jacket
# 27809    Full Sleeve Solid Men Casual Jacket
# 27971     Full Sleeve Printed Men Sweatshirt
# ...                                      ...
# 27949            Solid Men Black Track Pants
# 27993            Solid Men Black Track Pants
# 28100  Solid Men Polo Neck Dark Blue T-Shirt
# 28129             macroman m series Men Vest
# 29488          Striped Men Black Track Pants
#
#                                                      url
# 10767  https://www.flipkart.com/true-blue-2-piece-sel...
# 10801  https://www.flipkart.com/true-blue-2-piece-sol...
# 27627  https://www.flipkart.com/puma-full-sleeve-soli...
# 27809  https://www.flipkart.com/puma-full-sleeve-soli...
# 27971  https://www.flipkart.com/puma-full-sleeve-prin...
# ...                                                  ...
# 27949  https://www.flipkart.com/puma-solid-men-black-...
# 27993  https://www.flipkart.com/puma-solid-men-black-...
# 28100  https://www.flipkart.com/got-solid-men-polo-ne...
# 28129  https://www.flipkart.com/macroman-m-series-men...
# 29488  https://www.flipkart.com/ravilka-striped-men-b...
#
# [30000 rows x 17 columns]

# %%
df.sort_values(by=['selling_price','title'], ascending=False)
# Out:
#                                         _id  actual_price  average_rating  \
# 27130  d78eb403-fd7a-56da-b77f-d53b8891e64e       12999.0             3.7
# 27170  920cffd3-76c8-57d9-87bf-ee7208c02a13       12999.0             3.7
# 27410  3fc5f837-9d5a-527a-952d-b5b86c3ce5b2       12999.0             3.7
# 27627  a0b220a6-da00-5e0a-a64e-ef78921d8e5d       12999.0             3.7
# 27809  0aaf9f32-c62e-5f86-bd88-f5dc5c846b68       12999.0             3.7
# ...                                     ...           ...             ...
# 3335   86126d34-1556-5083-a194-e14e42b0f698           NaN             3.8
# 3338   859a62c6-4f73-5085-9041-f50ef86952be           NaN             3.8
# 3332   62440cdb-edf6-5480-8439-db0eb3d1dde7           NaN             3.8
# 3333   365ff976-224c-5d95-8704-ab33d4b5d1f6           NaN             3.8
# 13160  b87ae931-d006-540d-be1c-bcada2c20a46           NaN             2.7
#
#       brand                  category          crawled_at  \
# 27130    Pu  Clothing and Accessories 2021-02-11 01:04:35
# 27170    Pu  Clothing and Accessories 2021-02-11 01:04:55
# 27410    Pu  Clothing and Accessories 2021-02-11 01:07:01
# 27627    Pu  Clothing and Accessories 2021-02-11 01:09:12
# 27809    Pu  Clothing and Accessories 2021-02-11 01:10:48
# ...     ...                       ...                 ...
# 3335         Clothing and Accessories 2021-02-10 20:44:05
# 3338         Clothing and Accessories 2021-02-10 20:44:07
# 3332         Clothing and Accessories 2021-02-10 20:44:04
# 3333         Clothing and Accessories 2021-02-10 20:44:04
# 13160        Clothing and Accessories 2021-02-10 22:39:54
#
#                                              description  discount  \
# 27130                  Stylish and trendy jacket for men      50.0
# 27170                  Stylish and trendy jacket for men      50.0
# 27410                  Stylish and trendy jacket for men      50.0
# 27627                  Stylish and trendy jacket for men      40.0
# 27809                  Stylish and trendy jacket for men      50.0
# ...                                                  ...       ...
# 3335   Axmann Full Sleeve Pullover BY Axmann. Autumn ...       NaN
# 3338   Axmann Full Sleeve Pullover BY Axmann. Autumn ...       NaN
# 3332   Axmann Full Sleeve Pullover BY Axmann. Autumn ...       NaN
# 3333   Axmann Full Sleeve Pullover BY Axmann. Autumn ...       NaN
# 13160  Chris Gayle Limited Edition Signature Elevated...       NaN
#
#                                                   images  out_of_stock  \
# 27130  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27170  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27410  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27627  [https://rukminim1.flixcart.com/image/128/128/...         False
# 27809  [https://rukminim1.flixcart.com/image/128/128/...         False
# ...                                                  ...           ...
# 3335   [https://rukminim1.flixcart.com/image/128/128/...         False
# 3338   [https://rukminim1.flixcart.com/image/128/128/...         False
# 3332   [https://rukminim1.flixcart.com/image/128/128/...         False
# 3333   [https://rukminim1.flixcart.com/image/128/128/...         False
# 13160  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                     pid                                    product_details  \
# 27130  JCKFQF5K72AT2JDC  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27170  JCKFQF5K72AT2JDC  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27410  JCKFQF5K72AT2JDC  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27627  JCKFQF5KMJJ349H8  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# 27809  JCKFQF5K72AT2JDC  [{'Color': 'Black'}, {'Fabric': 'Cotton Blend'...
# ...                 ...                                                ...
# 3335   PLOFJQJJZHTYZBXT  [{'Ideal For': 'Men'}, {'Occasion': 'Casual'},...
# 3338   PLOFJQPA7ACHRYNZ  [{'Ideal For': 'Men'}, {'Occasion': 'Casual'},...
# 3332   PLOFJQJF5C2Y5CZQ  [{'Ideal For': 'Men'}, {'Occasion': 'Casual'},...
# 3333   PLOFJQJD8WJBCADX  [{'Ideal For': 'Men'}, {'Occasion': 'Casual'},...
# 13160  VESFKH7Y2CMYQRUT  [{'Neck': 'Round Neck'}, {'Pattern': 'Printed'...
#
#                 seller  selling_price            sub_category  \
# 27130  PumaSportsIndia        12999.0             Winter Wear
# 27170  PumaSportsIndia        12999.0             Winter Wear
# 27410  PumaSportsIndia        12999.0             Winter Wear
# 27627        RetailNet        12999.0             Winter Wear
# 27809  PumaSportsIndia        12999.0             Winter Wear
# ...                ...            ...                     ...
# 3335      ModaElementi            NaN             Winter Wear
# 3338      ModaElementi            NaN             Winter Wear
# 3332      ModaElementi            NaN             Winter Wear
# 3333      ModaElementi            NaN             Winter Wear
# 13160         Buy More            NaN  Innerwear and Swimwear
#
#                                             title  \
# 27130         Full Sleeve Solid Men Casual Jacket
# 27170         Full Sleeve Solid Men Casual Jacket
# 27410         Full Sleeve Solid Men Casual Jacket
# 27627         Full Sleeve Solid Men Casual Jacket
# 27809         Full Sleeve Solid Men Casual Jacket
# ...                                           ...
# 3335   AXMANN Round Neck Self Design Men Pullover
# 3338   AXMANN Round Neck Self Design Men Pullover
# 3332     AXMANN Round Neck Checkered Men Pullover
# 3333     AXMANN Round Neck Checkered Men Pullover
# 13160                          ATTIITUDE Men Vest
#
#                                                      url
# 27130  https://www.flipkart.com/puma-full-sleeve-soli...
# 27170  https://www.flipkart.com/puma-full-sleeve-soli...
# 27410  https://www.flipkart.com/puma-full-sleeve-soli...
# 27627  https://www.flipkart.com/puma-full-sleeve-soli...
# 27809  https://www.flipkart.com/puma-full-sleeve-soli...
# ...                                                  ...
# 3335   https://www.flipkart.com/axmann-round-neck-sel...
# 3338   https://www.flipkart.com/axmann-round-neck-sel...
# 3332   https://www.flipkart.com/axmann-round-neck-che...
# 3333   https://www.flipkart.com/axmann-round-neck-che...
# 13160  https://www.flipkart.com/attiitude-men-vest/p/...
#
# [30000 rows x 17 columns]

# %%
high_selling_price_df = df.sort_values(by='selling_price', ascending=False)

# %%
high_selling_price_df.drop_duplicates(subset=['title'], inplace=True)
px.bar(high_selling_price_df.head(1000),y='title', x='selling_price', color='out_of_stock',width= 1300)

# %%
px.bar_polar(high_selling_price_df.head(10),r = 'selling_price',
             theta='title',color='out_of_stock',width=1300)

# %%
px.scatter(high_selling_price_df, x='selling_price',y= 'discount',color='out_of_stock', hover_name='title')

# %%
px.scatter(high_selling_price_df, y='selling_price', x='actual_price',
    hover_name='title',trendline='ols')

# %%
fig = px.scatter(high_selling_price_df, y = 'selling_price',x='actual_price',
hover_name='title', trendline='ols')
fig.update_traces(marker=dict(size=10,color='red'),
selector=dict(mode='markers'))

# %%
fig = px.scatter(high_selling_price_df,y ='selling_price',x='actual_price',
                 hover_name = 'title' trendline='ols',
                  animation_frame='brand',animation_group='title')
